# %% [markdown]
# Exploring temperature data

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext dotenv
# %dotenv

# %%
import pandas as pd

# %%
df_temp = pd.read_csv("../data/raw/all_weather.csv")
df_temp.head()
# Out:
#                   date datatype            station attributes  value  \
# 0  2025-03-01T00:00:00     TMAX  GHCND:USW00094728   ,,W,2400   64.0
# 1  2025-03-01T00:00:00     TMIN  GHCND:USW00094728   ,,W,2400   27.0
# 2  2025-03-02T00:00:00     TMAX  GHCND:USW00094728   ,,W,2400   33.0
# 3  2025-03-02T00:00:00     TMIN  GHCND:USW00094728   ,,W,2400   20.0
# 4  2025-03-03T00:00:00     TMAX  GHCND:USW00094728   ,,W,2400   39.0
#
#        city     state
# 0  New York  New York
# 1  New York  New York
# 2  New York  New York
# 3  New York  New York
# 4  New York  New York

# %%
weather_pivot = df_temp.pivot_table(
    index=["date", "city", "state"],
    columns="datatype",
    values="value"
).reset_index()

# %%
weather_pivot.head(10)
# Out:
# datatype                 date      city       state  TMAX  TMIN
# 0         2025-03-01T00:00:00   Chicago    Illinois  34.0  22.0
# 1         2025-03-01T00:00:00   Houston       Texas  85.0  51.0
# 2         2025-03-01T00:00:00  New York    New York  64.0  27.0
# 3         2025-03-01T00:00:00   Phoenix     Arizona  85.0  58.0
# 4         2025-03-01T00:00:00   Seattle  Washington  62.0  37.0
# 5         2025-03-02T00:00:00   Chicago    Illinois  37.0  18.0
# 6         2025-03-02T00:00:00   Houston       Texas  74.0  55.0
# 7         2025-03-02T00:00:00  New York    New York  33.0  20.0
# 8         2025-03-02T00:00:00   Phoenix     Arizona  80.0  55.0
# 9         2025-03-02T00:00:00   Seattle  Washington  51.0  44.0

# %% [markdown]
# Exploring energy data

# %%
energy_df = pd.read_csv("../data/raw/all_energy.csv")
energy_df.head(2)
# Out:
#        period respondent                       respondent-name type type-name  \
# 0  2025-07-26       NYIS  New York Independent System Operator    D    Demand
# 1  2025-07-25       NYIS  New York Independent System Operator    D    Demand
#
#   timezone timezone-description   value    value-units      city     state
# 0  Eastern              Eastern  501454  megawatthours  New York  New York
# 1  Eastern              Eastern  575639  megawatthours  New York  New York

# %%
energy_pivot = energy_df.pivot_table(
    index= ['period', 'respondent-name', "timezone", "city", "state", "value-units"],
    columns=["type-name"],
    values="value"
).reset_index()

# %%
# Convert both to datetime
weather_pivot["date"] = pd.to_datetime(weather_pivot["date"]).dt.date
energy_pivot["period"] = pd.to_datetime(energy_pivot["period"]).dt.date

# rename period to date
energy_pivot = energy_pivot.rename(columns={'period':'date'})
energy_pivot.head()
# Out:
# type-name        date                              respondent-name  timezone  \
# 0          2025-03-01               Arizona Public Service Company  Mountain
# 1          2025-03-01  Electric Reliability Council of Texas, Inc.   Central
# 2          2025-03-01         New York Independent System Operator   Eastern
# 3          2025-03-01                     PJM Interconnection, LLC   Eastern
# 4          2025-03-01                           Seattle City Light   Pacific
#
# type-name      city       state    value-units     Demand  Net generation
# 0           Phoenix     Arizona  megawatthours    82316.0         58875.0
# 1           Houston       Texas  megawatthours  1059205.0       1057815.0
# 2          New York    New York  megawatthours   391122.0        365188.0
# 3           Chicago    Illinois  megawatthours  2110785.0       2206107.0
# 4           Seattle  Washington  megawatthours    25460.0          9262.0

# %%
# Merge on date, city, and state
merged_df = pd.merge(weather_pivot, energy_pivot, on=["date", "city", "state"], how="inner")

# %%
merged_df.head(20)
# Out:
#           date      city       state  TMAX  TMIN  \
# 0   2025-03-01   Chicago    Illinois  34.0  22.0
# 1   2025-03-01   Houston       Texas  85.0  51.0
# 2   2025-03-01  New York    New York  64.0  27.0
# 3   2025-03-01   Phoenix     Arizona  85.0  58.0
# 4   2025-03-01   Seattle  Washington  62.0  37.0
# 5   2025-03-02   Chicago    Illinois  37.0  18.0
# 6   2025-03-02   Houston       Texas  74.0  55.0
# 7   2025-03-02  New York    New York  33.0  20.0
# 8   2025-03-02   Phoenix     Arizona  80.0  55.0
# 9   2025-03-02   Seattle  Washington  51.0  44.0
# 10  2025-03-03   Chicago    Illinois  48.0  32.0
# 11  2025-03-03   Houston       Texas  79.0  63.0
# 12  2025-03-03  New York    New York  39.0  23.0
# 13  2025-03-03   Phoenix     Arizona  67.0  52.0
# 14  2025-03-03   Seattle  Washington  51.0  43.0
# 15  2025-03-04   Chicago    Illinois  48.0  43.0
# 16  2025-03-04   Houston       Texas  78.0  55.0
# 17  2025-03-04  New York    New York  52.0  34.0
# 18  2025-03-04   Phoenix     Arizona  73.0  49.0
# 19  2025-03-04   Seattle  Washington  49.0  41.0
#
#                                 respondent-name  timezone    value-units  \
# 0                      PJM Interconnection, LLC   Eastern  megawatthours
# 1   Electric Reliability Council of Texas, Inc.   Central  megawatthours
# 2          New York Independent System Operator   Eastern  megawatthours
# 3                Arizona Public Service Company  Mountain  megawatthours
# 4                            Seattle City Light   Pacific  megawatthours
# 5                      PJM Interconnection, LLC   Eastern  megawatthours
# 6   Electric Reliability Council of Texas, Inc.   Central  megawatthours
# 7          New York Independent System Operator   Eastern  megawatthours
# 8                Arizona Public Service Company  Mountain  megawatthours
# 9                            Seattle City Light   Pacific  megawatthours
# 10                     PJM Interconnection, LLC   Eastern  megawatthours
# 11  Electric Reliability Council of Texas, Inc.   Central  megawatthours
# 12         New York Independent System Operator   Eastern  megawatthours
# 13               Arizona Public Service Company  Mountain  megawatthours
# 14                           Seattle City Light   Pacific  megawatthours
# 15                     PJM Interconnection, LLC   Eastern  megawatthours
# 16  Electric Reliability Council of Texas, Inc.   Central  megawatthours
# 17         New York Independent System Operator   Eastern  megawatthours
# 18               Arizona Public Service Company  Mountain  megawatthours
# 19                           Seattle City Light   Pacific  megawatthours
#
#        Demand  Net generation
# 0   2110785.0       2206107.0
# 1   1059205.0       1057815.0
# 2    391122.0        365188.0
# 3     82316.0         58875.0
# 4     25460.0          9262.0
# 5   2360071.0       2402257.0
# 6   1051763.0       1049151.0
# 7    417602.0        381132.0
# 8     79043.0         60650.0
# 9     26038.0          9428.0
# 10  2450966.0       2529065.0
# 11  1130424.0       1128552.0
# 12   430754.0        371104.0
# 13    81732.0         64447.0
# 14    28238.0         11000.0
# 15  2239506.0       2352268.0
# 16  1094259.0       1096975.0
# 17   420282.0        378117.0
# 18    87334.0         58415.0
# 19    29252.0         10203.0

# %%
merged_df.to_csv("../data/processed/weather_energy_data.csv", index=False)

# %%
from src.data_fetcher import (
    get_temp_last_date,
    get_energy_last_date,
    get_cities
)

# %%
# get temp

start_temp = get_temp_last_date("../data/raw/all_weather.csv")
print(start_temp)
print(type(start_temp))
# Out:
# 2025-07-27
# <class 'datetime.date'>

# %%
# get enrgy

start_energy = get_energy_last_date("../data/raw/all_energy.csv")
print(start_energy)
print(type(start_energy))
# Out:
# 2025-07-27
# <class 'datetime.date'>

# %%
city = get_cities("../config/config.yaml")

for i in city:
    print(i)
# Out:
# {'city': 'New York', 'state': 'New York', 'station': 'GHCND:USW00094728', 'region': 'NYIS', 'timezone': 'Eastern'}
# {'city': 'Chicago', 'state': 'Illinois', 'station': 'GHCND:USW00094846', 'region': 'PJM', 'timezone': 'Eastern'}
# {'city': 'Houston', 'state': 'Texas', 'station': 'GHCND:USW00012960', 'region': 'ERCO', 'timezone': 'Central'}
# {'city': 'Phoenix', 'state': 'Arizona', 'station': 'GHCND:USW00023183', 'region': 'AZPS', 'timezone': 'Mountain'}
# {'city': 'Seattle', 'state': 'Washington', 'station': 'GHCND:USW00024233', 'region': 'SCL', 'timezone': 'Pacific'}

# %%
import datetime
print(datetime.date.today() + datetime.timedelta(days=1))
# Out:
# 2025-07-31

# %%
if start_energy > datetime.date.today():
    print("hello")
elif start_energy < datetime.date.today():
    print("world")
else:
    print("none")
# Out:
# world

# %%
import pandas as pd
from datetime import datetime, timedelta

# 1. Load existing CSV
weather_path = "../data/raw/all_weather.csv"
df = pd.read_csv(weather_path, parse_dates=["date"])
df.head(2)
# Out:
#         date datatype            station attributes  value      city     state
# 0 2025-03-01     TMAX  GHCND:USW00094728   ,,W,2400   64.0  New York  New York
# 1 2025-03-01     TMIN  GHCND:USW00094728   ,,W,2400   27.0  New York  New York

# %%
df["date"] = pd.to_datetime(df["date"])

# 2. Get last date per city
last_dates = df.groupby("city")["date"].max().to_dict()
print(last_dates)
# Out:
# {'Chicago': Timestamp('2025-07-25 00:00:00'), 'Houston': Timestamp('2025-07-27 00:00:00'), 'New York': Timestamp('2025-07-25 00:00:00'), 'Phoenix': Timestamp('2025-07-27 00:00:00'), 'Seattle': Timestamp('2025-07-27 00:00:00')}

# %%
for key, value in

# %%
import yaml
with open("../config/config.yaml") as f:
    data = yaml.safe_load(f)

cities_list = data["cities"]

# print(cities_list)

# %%
# 3. Use it to fetch data for each city
for city_info in cities_list:  # your YAML cities
    city = city_info["city"]

    
    # Use last saved date + 1 day or a default start
    start_date = last_dates.get(city, pd.Timestamp("2023-01-01")) + timedelta(days=1)
    # end_date = datetime.today()
    print(city, start_date)
# Out:
# New York 2025-07-26 00:00:00
# Chicago 2025-07-26 00:00:00
# Houston 2025-07-28 00:00:00
# Phoenix 2025-07-28 00:00:00
# Seattle 2025-07-28 00:00:00
